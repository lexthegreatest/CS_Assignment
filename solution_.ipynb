# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats

# %% [markdown]
# ### Titles of the pivotal papers:

# %% [markdown]
# 1. MCC Van Dyke et al., 2019 : Fantastic yeasts and where to find them: the hidden diversity of dimorphic fungal pathogens
#
# 2. JT Harvey, Applied Ergonomics, 2002: An analysis of the forces required to drag sheep over various surfaces
#
# 3. DW Ziegler et al., 2005: The neurocognitive effects of alcohol on adolescents and college students

# %%
os.getcwd()
# Out:
# '/Users/aleksandar/Documents/GitHub/CS_Assignment'

# %%
current_directory = os.getcwd()

# csv file name
csv_file_name = 'istherecorrelation.csv'

# full path to the csv file
csv_file_path = os.path.join(current_directory, csv_file_name)

# read the file
df = pd.read_csv(csv_file_path, delimiter=';')

# %%
display(df)
# Out:
#     Year WO [x1000]  NL Beer consumption [x1000 hectoliter]
# 0   2006      205,9                                   11402
# 1   2007      208,6                                   11492
# 2   2008      212,7                                   11450
# 3   2009      220,5                                   11502
# 4   2010      233,2                                   11474
# 5   2011      242,4                                   11480
# 6   2012      245,4                                   11452
# 7   2013      241,4                                   11484
# 8   2014      250,2                                   11555
# 9   2015      255,7                                   11601
# 10  2016      261,2                                   11731
# 11  2017      267,9                                   11862
# 12  2018      280,1                                   12048

# %%
df['WO [x1000]'] = pd.to_numeric(df['WO [x1000]'].str.replace(',', '.'))

# %%
# Pearson correlation coefficient
correlation_coefficient = df['WO [x1000]'].corr(df['NL Beer consumption [x1000 hectoliter]'])

# %%
# the plot
fig, ax1 = plt.subplots(figsize=(8, 6), dpi=300)  # Set the figure size and DPI

# the primary y-axis (left)
ax1.plot(df['Year'], df['WO [x1000]'], label='WO [x1000]', marker='o', linestyle='-', color='b')
ax1.set_xlabel('Year')
ax1.set_ylabel('WO [x1000]', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# create a secondary y-axis (right)
ax2 = ax1.twinx()

# the secondary y-axis (right)
ax2.plot(df['Year'], df['NL Beer consumption [x1000 hectoliter]'], label='NL Beer consumption [x1000 hectoliter]', marker='s', linestyle='--', color='r')
ax2.set_ylabel('NL Beer consumption [x1000 hectoliter]', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# external legends for both axes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(1.2, 1), title='Legend')

# add the Pearson correlation coefficient to the plot
plt.annotate(f'Pearson correlation coefficient: {correlation_coefficient:.2f}', xy=(0.1, 0.9),
             xycoords='axes fraction', fontsize=10, color='g')

# display the plot
plt.show()

# %% [markdown]
# Number of university students (WO) correlates highly with the annual beer consumption in the Netherlands over the pre-Covid period, with both damping during the Eurozone crisis; and with the overall beer consumption stagnating ex-post the global financial crisis of 2007-8.
